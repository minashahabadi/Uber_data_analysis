# %%
# %pylab inline
import pandas 
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load CSV file into memory

# %%
data = pandas.read_csv(r'C:\Users\user\Desktop\dataset\Uber\uberdata.csv')

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base
# 564511  4/30/2014 23:22:00  40.7640 -73.9744  B02764
# 564512  4/30/2014 23:26:00  40.7629 -73.9672  B02764
# 564513  4/30/2014 23:31:00  40.7443 -73.9889  B02764
# 564514  4/30/2014 23:32:00  40.6756 -73.9405  B02764
# 564515  4/30/2014 23:48:00  40.6880 -73.9608  B02764

# %% [markdown]
# ## Convert datetime and add some useful columns

# %%
data['Date/Time'] = data['Date/Time'].map(pandas.to_datetime)

# %%
type(data['Date/Time'])
# Out:
# pandas.core.series.Series

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764

# %%
def get_dom(dt):
    return dt.day
data['dom'] = data['Date/Time'].map(get_dom)

# %%
dt = data['Date/Time'][500000]

# %%
def get_weekday(dt):
    return dt.weekday()
data['weekday']= data['Date/Time'].map(get_weekday)

def get_hour(dt):
    return dt.hour
data['hour'] = data['Date/Time'].map(get_hour)

data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30        2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30        2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30        2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30        2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30        2    23

# %% [markdown]
# ## analysis
# ## analyze the DoM

# %%
hist(data.dom);

# %%
hist(data.dom, bins=30, rwidth=0.8, range=(0.5,30.5))
xlabel('date of the month')
ylabel('frequency')
title('Frequency by DoM - uber - Apr 2014');

# %%
def count_rows(rows):
    return len(rows)
by_date= data.groupby('dom').apply(count_rows)
by_date
# Out:
# dom
# 1     14546
# 2     17474
# 3     20701
# 4     26714
# 5     19521
# 6     13445
# 7     19550
# 8     16188
# 9     16843
# 10    20041
# 11    20420
# 12    18170
# 13    12112
# 14    12674
# 15    20641
# 16    17717
# 17    20973
# 18    18074
# 19    14602
# 20    11017
# 21    13162
# 22    16975
# 23    20346
# 24    23352
# 25    25095
# 26    24925
# 27    14677
# 28    15475
# 29    22835
# 30    36251
# dtype: int64

# %%
bar(range(1,31),by_date);

# %%
by_date_sorted = by_date.sort_values()
by_date_sorted
# Out:
# dom
# 20    11017
# 13    12112
# 14    12674
# 21    13162
# 6     13445
# 1     14546
# 19    14602
# 27    14677
# 28    15475
# 8     16188
# 9     16843
# 22    16975
# 2     17474
# 16    17717
# 18    18074
# 12    18170
# 5     19521
# 7     19550
# 10    20041
# 23    20346
# 11    20420
# 15    20641
# 3     20701
# 17    20973
# 29    22835
# 24    23352
# 26    24925
# 25    25095
# 4     26714
# 30    36251
# dtype: int64

# %%
bar(range(1,31),by_date_sorted)
xticks(range(1,31), by_date_sorted.index)
xlabel('date of the month')
ylabel('frequency')
title('Frequency by DoM - uber - Apr 2014');

# %% [markdown]
# ## analyze the hour

# %%
hist(data.hour, bins=24, range=(0.5, 24));

# %% [markdown]
# ## analyze the hour

# %%
hist(data.weekday, bins=7, range=(-0.5, 6.5), rwidth = 0.8, color = '#AA6666', alpha=0.5)
xticks(range(7), 'Mon Tue Wed Thu Fri Sat Sun'.split());

# %% [markdown]
# ## Cross analysis (hour, dow)

# %%
by_cross = data.groupby('weekday hour'.split()).apply(count_rows).unstack()

# %%
seaborn.heatmap(by_cross);

# %% [markdown]
# ## by lat and lon

# %%
hist(data['Lat'],bins=100, range = (40.5, 41));

# %%
hist(data['Lon'],bins=100, range = (-74.1, -73.9));
# Out:
# ''

# %%
hist(data['Lon'],bins=100, range = (-74.1, -73.9), color='g', alpha=0.5, label='longitude')
grid()
legend(loc='upper left')
twiny()
hist(data['Lat'],bins=100, range = (40.5, 41), color='r', alpha=0.5, label = 'latitude')
legend(loc='best');

# %%
plot(data['Lat'], '*', ms=20, color = 'red', label='lat')
plot(data['Lon'], '^', ms=20, color = 'green', label='lon')
xlim(0,100);

# %%
figure(figsize(20, 20))
plot(data['Lon'],data['Lat'],'.', ms=1 , alpha=0.2)
xlim(-74.2, -73.7)
ylim(40.7, 41)
# Out:
# (40.7, 41.0)
